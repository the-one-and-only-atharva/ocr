# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
from download import download_image
from ocr import ocr


def show(path):
    plt.imshow(imread(path))
    plt.axis("off")
    plt.show()

# %%
url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTXMtzshi1M0e2_j2qCfNx_juTeGaqa0TMXzrfN5cqfAw&s=10'
dest = download_image(url, "download/aadhaar")
dest
# Out:
# PosixPath('download/aadhaar/file.png')

# %%
show(dest)

# %%
ocr(dest)
# Out:
# {'name': 'Basant Raj',
#  'dob': '01/01/2000',
#  'gender': 'Male',
#  'aadhaar_number': '1234 5678 9101'}

# %%
url2 = 'https://content.jdmagicbox.com/comp/ahmedabad/j5/079pxx79.xx79.160714180141.v5j5/catalogue/aadhar-card-waley-ambawadi-ahmedabad-aadhaar-card-offices-5rf4hs4zrt-250.jpg'
dest2 = download_image(url2, "download/aadhaar2")
dest2
# Out:
# PosixPath('download/aadhaar2/file.jpg')

# %%
show(dest2)

# %%
ocr(dest2)
# Out:
# {'name': 'Isharafik',
#  'dob': '01/01/1981',
#  'gender': 'Male',
#  'aadhaar_number': '7521 2383 7668'}
