# %%
from download import download_image

# %%
url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT8-Np3Q8B29fcByHQqTDc4Gapx27KbzPyr5PLdYO0s_mZVtHAjpq1O6uM&s=10'

dest = download_image(url, "download/cat")
print(dest)
# Out:
# download/cat/file.jpg
